# %%
import numpy as np
import cv2
import os
import glob

# %%
p = glob.glob(r"C:\Users\Sergey\Desktop\Net_tom\Dataset_fablab\other\*")
print(p, '\n')
print(len(p))
# Out:
# ['C:\\Users\\Sergey\\Desktop\\Net_tom\\Dataset_fablab\\Tomatoes\\IMG_20190309_153703.jpg', 'C:\\Users\\Sergey\\Desktop\\Net_tom\\Dataset_fablab\\Tomatoes\\IMG_20190309_153706.jpg', 'C:\\Users\\Sergey\\Desktop\\Net_tom\\Dataset_fablab\\Tomatoes\\IMG_20190309_153710.jpg', 'C:\\Users\\Sergey\\Desktop\\Net_tom\\Dataset_fablab\\Tomatoes\\IMG_20190309_153712.jpg', 'C:\\Users\\Sergey\\Desktop\\Net_tom\\Dataset_fablab\\Tomatoes\\IMG_20190309_153716.jpg', 'C:\\Users\\Sergey\\Desktop\\Net_tom\\Dataset_fablab\\Tomatoes\\IMG_20190309_153720.jpg', 'C:\\Users\\Sergey\\Desktop\\Net_tom\\Dataset_fablab\\Tomatoes\\IMG_20190309_153725.jpg', 'C:\\Users\\Sergey\\Desktop\\Net_tom\\Dataset_fablab\\Tomatoes\\IMG_20190309_153728.jpg', 'C:\\Users\\Sergey\\Desktop\\Net_tom\\Dataset_fablab\\Tomatoes\\IMG_20190309_153730.jpg', 'C:\\Users\\Sergey\\Desktop\\Net_tom\\Dataset_fablab\\Tomatoes\\IMG_20190309_153733.jpg', 'C:\\Users\\Sergey\\Desktop\\Net_tom\\Dataset_fablab\\Tomatoes\\IMG_20190309_153735.jpg', 'C:\\Us
# ...

# %%
while True:
    for i in p:
        img = cv2.imread(i)
        cv2.imshow(i, img)
    
    if cv2.waitKey(30) == ord('q'):
        break
#cap.release()
cv2.destroyAllWindows()

# %%
i = 0
for path in p:
    img = cv2.imread(path)
    if not img is None:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = cv2.resize(img, (300, 300))
        cv2.imwrite(r"C:\Users\Sergey\Desktop\Net_tom\Dataset_fablab_edit\other\\" + str(i) + ".jpg", img)
        int(i)
        i = i + 1
